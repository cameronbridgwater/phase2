# %% [markdown]
# ## Calculator
# Create a program that takes two numbers from a user (input) and calculates their sum and difference.
#
# Example
#
#     Input first number: 10
#     Input second number: 5
#
#     sum: 15
#     difference: 5

# %%
def sum_difference_calc(num1, num2):
    return f"sum: {num1+num2}\ndifference: {num1-num2}"

print(sum_difference_calc(10,5))
...
# Out:
# sum: 15
# difference: 5
# Ellipsis

# %% [markdown]
# ## Loop
#
# Create a Loop that prints "I understand loops!" 10 times.

# %%
def repeat():
    for i in range(10):
        print("I understand loops")

repeat()
...
# Out:
# I understand loops
# I understand loops
# I understand loops
# I understand loops
# I understand loops
# I understand loops
# I understand loops
# I understand loops
# I understand loops
# I understand loops
# Ellipsis

# %% [markdown]
# ## FizzBuzz
#
# Create a while loop that goes through integers of 1 to 50 and prints "Fizz" for multiples of 3, and "Buzz" for multiples of "5", and "FizzBuzz" for multiples of 3 and 5.

# %%
def fizz_buzz():
    for i in range (1,51):
        if i % 3 == 0 and i % 5 == 0:
            print("FizzBuzz") 
        if i % 3 == 0:
            print("Fizz") 
        if i % 5 == 0:
            print("Buzz")
fizz_buzz()
...
# Out:
# Fizz
# Buzz
# Fizz
# Fizz
# Buzz
# Fizz
# FizzBuzz
# Fizz
# Buzz
# Fizz
# Buzz
# Fizz
# Fizz
# Buzz
# Fizz
# FizzBuzz
# Fizz
# Buzz
# Fizz
# Buzz
# Fizz
# Fizz
# Buzz
# Fizz
# FizzBuzz
# Fizz
# Buzz
# Fizz
# Buzz
# Ellipsis
